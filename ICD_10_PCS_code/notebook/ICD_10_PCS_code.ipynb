# %% [markdown]
# ## ICD_10_PCS_code Dataset Cleanup

# %% [markdown]
# ### Description

# %% [markdown]
# While developing a personal portfolio project involving a medical treatments dimension table, I sourced and integrated two public datasets to create a comprehensive list of U.S. medical procedure codes.
#
# The project involved cleaning and merging the following files:
#
# HCUP ICD-10-PCS Code File: Provides the official procedure code set and labels.
#
# CDC NHSN ICD-10-PCS Code Map: Offers additional details and classifications for procedures.
#
# The objective was to combine, standardize, and clean the columns from both sources to produce a complete, analysis-ready dataset of medical procedure details.

# %%
import pandas as pd

# %% [markdown]
# ### Initial Data Import and Inspection
#
# Imported both source files into Pandas DataFrames.
#
# Conducted an initial inspection to understand the structure, column names, and data quality of each dataset.

# %%
ICD_10_PCS_code = pd.read_csv("D:\Porte\datasets\ehph\PClassR_v2024-1_03072024.csv", header=0)

# %%
ICD_10_PCS_code.head(10)
# Out:
#   Procedure Classes Refined for ICD-10-PCS,  v2024.1  \
# 0                                  'ICD-10-PCS CODE'
# 1                                          '0016070'
# 2                                          '0016071'
# 3                                          '0016072'
# 4                                          '0016073'
# 5                                          '0016074'
# 6                                          '0016075'
# 7                                          '0016076'
# 8                                          '0016077'
# 9                                          '0016078'
#
#                                           Unnamed: 1         Unnamed: 2  \
# 0                       ICD-10-PCS CODE DESCRIPTION'  'PROCEDURE CLASS'
# 1  Bypass Cerebral Ventricle to Nasopharynx with ...                  4
# 2  Bypass Cerebral Ventricle to Mastoid Sinus wit...                  4
# 3  Bypass Cerebral Ventricle to Atrium with Autol...                  4
# 4  Bypass Cerebral Ventricle to Blood Vessel with...                  4
# 5  Bypass Cerebral Ventricle to Pleural Cavity wi...                  4
# 6  Bypass Cerebral Ventricle to Intestine with Au...                  4
# 7  Bypass Cerebral Ventricle to Peritoneal Cavity...                  4
# 8  Bypass Cerebral Ventricle to Urinary Tract wit...                  4
# 9  Bypass Cerebral Ventricle to Bone Marrow with ...                  4
#
#                Unnamed: 3
# 0  'PROCEDURE CLASS NAME'
# 1       Major Therapeutic
# 2       Major Therapeutic
# 3       Major Therapeutic
# 4       Major Therapeutic
# 5       Major Therapeutic
# 6       Major Therapeutic
# 7       Major Therapeutic
# 8       Major Therapeutic
# 9       Major Therapeutic

# %%
ICD_10_PCS_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81710 entries, 0 to 81709
# Data columns (total 4 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Procedure Classes Refined for ICD-10-PCS,  v2024.1  81710 non-null  object
#  1   Unnamed: 1                                          81710 non-null  object
#  2   Unnamed: 2                                          81710 non-null  object
#  3   Unnamed: 3                                          81710 non-null  object
# dtypes: object(4)
# memory usage: 2.5+ MB

# %%
ICD_10_PCS_code.dtypes
# Out:
# Procedure Classes Refined for ICD-10-PCS,  v2024.1    object
# Unnamed: 1                                            object
# Unnamed: 2                                            object
# Unnamed: 3                                            object
# dtype: object

# %% [markdown]
# ### Column Name Correction
#
# 1. Identified that the column names were incorrectly parsed and placed in the first row of the data.
#
# 2. Corrected this by reassigning the first row as the new column headers.
#
# 3. Cleaned the new column names by removing single quotes (') to ensure consistency and ease of use.

# %%
# Take the first row as header
ICD_10_PCS_code.columns = ICD_10_PCS_code.iloc[0]  

# Drop the first row from data
ICD_10_PCS_code = ICD_10_PCS_code[1:].reset_index(drop=True)

ICD_10_PCS_code.head()
# Out:
# 0 'ICD-10-PCS CODE'                       ICD-10-PCS CODE DESCRIPTION'  \
# 0         '0016070'  Bypass Cerebral Ventricle to Nasopharynx with ...
# 1         '0016071'  Bypass Cerebral Ventricle to Mastoid Sinus wit...
# 2         '0016072'  Bypass Cerebral Ventricle to Atrium with Autol...
# 3         '0016073'  Bypass Cerebral Ventricle to Blood Vessel with...
# 4         '0016074'  Bypass Cerebral Ventricle to Pleural Cavity wi...
#
# 0 'PROCEDURE CLASS' 'PROCEDURE CLASS NAME'
# 0                 4      Major Therapeutic
# 1                 4      Major Therapeutic
# 2                 4      Major Therapeutic
# 3                 4      Major Therapeutic
# 4                 4      Major Therapeutic

# %%
# Remove single quotes from headers
ICD_10_PCS_code.columns = ICD_10_PCS_code.columns.str.replace("'", "", regex=False)

# %% [markdown]
# ### Data Cleaning for First Column:
#
# Observed that all values in the first column 'ICD-10-PCS CODE' were stored as strings enclosed in single quotes.
#
# Executed a string operation to strip the leading and trailing single quotes from every entry in ICD-10-PCS CODE column, converting them into clean, standard string values.

# %%
# Remove single quotes from the column values
ICD_10_PCS_code["ICD-10-PCS CODE"] = ICD_10_PCS_code["ICD-10-PCS CODE"].str.replace("'", "", regex=False)

# Check first rows
ICD_10_PCS_code["ICD-10-PCS CODE"].head()
# Out:
# 0    0016070
# 1    0016071
# 2    0016072
# 3    0016073
# 4    0016074
# Name: ICD-10-PCS CODE, dtype: object

# %%
ICD_10_PCS_code.head()
# Out:
# 0 ICD-10-PCS CODE                        ICD-10-PCS CODE DESCRIPTION  \
# 0         0016070  Bypass Cerebral Ventricle to Nasopharynx with ...
# 1         0016071  Bypass Cerebral Ventricle to Mastoid Sinus wit...
# 2         0016072  Bypass Cerebral Ventricle to Atrium with Autol...
# 3         0016073  Bypass Cerebral Ventricle to Blood Vessel with...
# 4         0016074  Bypass Cerebral Ventricle to Pleural Cavity wi...
#
# 0 PROCEDURE CLASS PROCEDURE CLASS NAME
# 0               4    Major Therapeutic
# 1               4    Major Therapeutic
# 2               4    Major Therapeutic
# 3               4    Major Therapeutic
# 4               4    Major Therapeutic

# %% [markdown]
# ### Secondary Dataset Import and Inspection
#
# Imported the second dataset (CDC NHSN file) and performed a similar preliminary check to understand its schema and identify key columns for the merge.

# %%
lookup_df = pd.read_excel("D:\Reports\icd10-pcs-pcm-nhsn-opc.xlsx", sheet_name="ALL 2025 ICD-10-PCS CODES", header=0)

# %%
lookup_df.head(10)
# Out:
#   Procedure Code Category ICD-10-PCS Codes  \
# 0                     AAA         04B00ZZ
# 1                     AAA         04B04ZZ
# 2                     AAA         04R007Z
# 3                     AAA         04R00JZ
# 4                     AAA         04R00KZ
# 5                     AAA         04R047Z
# 6                     AAA         04R04JZ
# 7                     AAA         04R04KZ
# 8                     AMP         0X600ZZ
# 9                     AMP         0X610ZZ
#
#                          Procedure Code Descriptions Code Status
# 0         Excision of Abdominal Aorta, Open Approach   No change
# 1  Excision of Abdominal Aorta, Percutaneous Endo...   No change
# 2  Replacement of Abdominal Aorta with Autologous...   No change
# 3  Replacement of Abdominal Aorta with Synthetic ...   No change
# 4  Replacement of Abdominal Aorta with Nonautolog...   No change
# 5  Replacement of Abdominal Aorta with Autologous...   No change
# 6  Replacement of Abdominal Aorta with Synthetic ...   No change
# 7  Replacement of Abdominal Aorta with Nonautolog...   No change
# 8     Detachment at Right Forequarter, Open Approach   No change
# 9      Detachment at Left Forequarter, Open Approach   No change

# %% [markdown]
# ### Merging to Add Missing Attribute
#
# Identified a valuable column, 'Procedure Code Category', present in the second dataset but missing from the first.
#
# Performed a lookup using the common key: ICD-10-PCS Code, to accurately add the category column to the primary dataset, thereby enriching it.

# %%
# Create a dictionary from the lookup table
lookup_dict = dict(zip(lookup_df['ICD-10-PCS Codes'], lookup_df['Procedure Code Category']))

# %%
# Add the lookup column
ICD_10_PCS_code['Category'] = ICD_10_PCS_code['ICD-10-PCS CODE'].map(lookup_dict)

# %%
ICD_10_PCS_code.head(10)
# Out:
# 0 ICD-10-PCS CODE                        ICD-10-PCS CODE DESCRIPTION  \
# 0         0016070  Bypass Cerebral Ventricle to Nasopharynx with ...
# 1         0016071  Bypass Cerebral Ventricle to Mastoid Sinus wit...
# 2         0016072  Bypass Cerebral Ventricle to Atrium with Autol...
# 3         0016073  Bypass Cerebral Ventricle to Blood Vessel with...
# 4         0016074  Bypass Cerebral Ventricle to Pleural Cavity wi...
# 5         0016075  Bypass Cerebral Ventricle to Intestine with Au...
# 6         0016076  Bypass Cerebral Ventricle to Peritoneal Cavity...
# 7         0016077  Bypass Cerebral Ventricle to Urinary Tract wit...
# 8         0016078  Bypass Cerebral Ventricle to Bone Marrow with ...
# 9         001607A  Bypass Cerebral Ventricle to Subgaleal Space w...
#
# 0 PROCEDURE CLASS PROCEDURE CLASS NAME Category
# 0               4    Major Therapeutic     VSHN
# 1               4    Major Therapeutic     VSHN
# 2               4    Major Therapeutic     VSHN
# 3               4    Major Therapeutic     VSHN
# 4               4    Major Therapeutic     VSHN
# 5               4    Major Therapeutic     VSHN
# 6               4    Major Therapeutic     VSHN
# 7               4    Major Therapeutic     VSHN
# 8               4    Major Therapeutic     VSHN
# 9               4    Major Therapeutic     VSHN

# %% [markdown]
# ### Handling a Complex Column
#
# Focused on the 'ICD-10-PCS CODE DESCRIPTION' column, which contained multiple values concatenated into a single string using commas.
#
# Recognized that a simple split on the comma delimiter was not feasible due to an inconsistent number of values per row, which would have created an unpredictable number of columns and messy data.
#
# Devised and implemented an alternative solution to parse this complex field effectively without compromising data integrity.

# %%
# Split into parts
split_cols = ICD_10_PCS_code['ICD-10-PCS CODE DESCRIPTION'].str.split(', ', expand=True)

# Inspect how many parts you actually have
print(split_cols)
# Out:
#                                                        0  \
# 0      Bypass Cerebral Ventricle to Nasopharynx with ...
# 1      Bypass Cerebral Ventricle to Mastoid Sinus wit...
# 2      Bypass Cerebral Ventricle to Atrium with Autol...
# 3      Bypass Cerebral Ventricle to Blood Vessel with...
# 4      Bypass Cerebral Ventricle to Pleural Cavity wi...
# ...                                                  ...
# 81704                           Measurement of Infection
# 81705                           Measurement of Infection
# 81706  Extracorporeal Introduction of Endothelial Dam...
# 81707  Extracorporeal Introduction of Taurolidine Ant...
# 81708  Extracorporeal Introduction of Nafamostat Anti...
#
#                                                        1  \
# 0                                          Open Approach
# 1                                          Open Approach
# 2                                          Open Approach
# 3                                          Open Approach
# 4                                          Open Approach
# ...                                                  ...
# 81704  Nasopharyngeal Fluid SARS-CoV-2 Polymerase Cha...
# 81705  Lower Respiratory Fluid Nucleic Acid-base Micr...
# 81706                             New Technology Group 3
# 81707                             New Technology Group 8
# 81708                             New Technology Group 7
#
#                             2     3     4
# 0                        None  None  None
# 1                        None  None  None
# 2                        None  None  None
# 3                        None  None  None
# 4                        None  None  None
# ...                       ...   ...   ...
# 81704  New Technology Group 7  None  None
# 81705  New Technology Group 6  None  None
# 81706                    None  None  None
# 81707                    None  None  None
# 81708                    None  None  None
#
# [81709 rows x 5 columns]

# %%
split_cols.columns = ['Procedure', 'Anatomy', 'Qualifier', 'Device_or_Method', 'Approach_or_Group']

ICD_10_PCS_code = pd.concat([ICD_10_PCS_code, split_cols], axis=1)

# %%
ICD_10_PCS_code.head(10)
# Out:
#   ICD-10-PCS CODE                        ICD-10-PCS CODE DESCRIPTION  \
# 0         0016070  Bypass Cerebral Ventricle to Nasopharynx with ...
# 1         0016071  Bypass Cerebral Ventricle to Mastoid Sinus wit...
# 2         0016072  Bypass Cerebral Ventricle to Atrium with Autol...
# 3         0016073  Bypass Cerebral Ventricle to Blood Vessel with...
# 4         0016074  Bypass Cerebral Ventricle to Pleural Cavity wi...
# 5         0016075  Bypass Cerebral Ventricle to Intestine with Au...
# 6         0016076  Bypass Cerebral Ventricle to Peritoneal Cavity...
# 7         0016077  Bypass Cerebral Ventricle to Urinary Tract wit...
# 8         0016078  Bypass Cerebral Ventricle to Bone Marrow with ...
# 9         001607A  Bypass Cerebral Ventricle to Subgaleal Space w...
#
#   PROCEDURE CLASS PROCEDURE CLASS NAME Category  \
# 0               4    Major Therapeutic     VSHN
# 1               4    Major Therapeutic     VSHN
# 2               4    Major Therapeutic     VSHN
# 3               4    Major Therapeutic     VSHN
# 4               4    Major Therapeutic     VSHN
# 5               4    Major Therapeutic     VSHN
# 6               4    Major Therapeutic     VSHN
# 7               4    Major Therapeutic     VSHN
# 8               4    Major Therapeutic     VSHN
# 9               4    Major Therapeutic     VSHN
#
#                                            Procedure        Anatomy Qualifier  \
# 0  Bypass Cerebral Ventricle to Nasopharynx with ...  Open Approach      None
# 1  Bypass Cerebral Ventricle to Mastoid Sinus wit...  Open Approach      None
# 2  Bypass Cerebral Ventricle to Atrium with Autol...  Open Approach      None
# 3  Bypass Cerebral Ventricle to Blood Vessel with...  Open Approach      None
# 4  Bypass Cerebral Ventricle to Pleural Cavity wi...  Open Approach      None
# 5  Bypass Cerebral Ventricle to Intestine with Au...  Open Approach      None
# 6  Bypass Cerebral Ventricle to Peritoneal Cavity...  Open Approach      None
# 7  Bypass Cerebral Ventricle to Urinary Tract wit...  Open Approach      None
# 8  Bypass Cerebral Ventricle to Bone Marrow with ...  Open Approach      None
# 9  Bypass Cerebral Ventricle to Subgaleal Space w...  Open Approach      None
#
#   Device_or_Method Approach_or_Group
# 0             None              None
# 1             None              None
# 2             None              None
# 3             None              None
# 4             None              None
# 5             None              None
# 6             None              None
# 7             None              None
# 8             None              None
# 9             None              None

# %% [markdown]
# ### Removal of Redundant Column
#
# After successfully extracting the necessary information from the 'ICD-10-PCS CODE DESCRIPTION' column, it was determined that the original column had become redundant and offered no further analytical value.
#
# This column was dropped from the final DataFrame to simplify the dataset and improve clarity.

# %%
# Drop the original description column because its redundant
ICD_10_PCS_code = ICD_10_PCS_code.drop(columns=['ICD-10-PCS CODE DESCRIPTION'])

# %%
ICD_10_PCS_code.head(10)
# Out:
#   ICD-10-PCS CODE PROCEDURE CLASS PROCEDURE CLASS NAME Category  \
# 0         0016070               4    Major Therapeutic     VSHN
# 1         0016071               4    Major Therapeutic     VSHN
# 2         0016072               4    Major Therapeutic     VSHN
# 3         0016073               4    Major Therapeutic     VSHN
# 4         0016074               4    Major Therapeutic     VSHN
# 5         0016075               4    Major Therapeutic     VSHN
# 6         0016076               4    Major Therapeutic     VSHN
# 7         0016077               4    Major Therapeutic     VSHN
# 8         0016078               4    Major Therapeutic     VSHN
# 9         001607A               4    Major Therapeutic     VSHN
#
#                                            Procedure        Anatomy Qualifier  \
# 0  Bypass Cerebral Ventricle to Nasopharynx with ...  Open Approach      None
# 1  Bypass Cerebral Ventricle to Mastoid Sinus wit...  Open Approach      None
# 2  Bypass Cerebral Ventricle to Atrium with Autol...  Open Approach      None
# 3  Bypass Cerebral Ventricle to Blood Vessel with...  Open Approach      None
# 4  Bypass Cerebral Ventricle to Pleural Cavity wi...  Open Approach      None
# 5  Bypass Cerebral Ventricle to Intestine with Au...  Open Approach      None
# 6  Bypass Cerebral Ventricle to Peritoneal Cavity...  Open Approach      None
# 7  Bypass Cerebral Ventricle to Urinary Tract wit...  Open Approach      None
# 8  Bypass Cerebral Ventricle to Bone Marrow with ...  Open Approach      None
# 9  Bypass Cerebral Ventricle to Subgaleal Space w...  Open Approach      None
#
#   Device_or_Method Approach_or_Group
# 0             None              None
# 1             None              None
# 2             None              None
# 3             None              None
# 4             None              None
# 5             None              None
# 6             None              None
# 7             None              None
# 8             None              None
# 9             None              None

# %% [markdown]
# ### Creating a Surrogate Key
#
# To ensure seamless and efficient integration with the fact table in a data model, I generated a unique ID column.
#
# This surrogate key provides a clean, non-natural primary key for the dimension table, insulating the data model from any future changes in the natural ICD-10-PCS codes and improving join performance.

# %%
# Create an auto-increment ID starting at 1
ICD_10_PCS_code.insert(0, 'ID', range(1, len(ICD_10_PCS_code) + 1))

# %%
ICD_10_PCS_code.head(10)
# Out:
#    ID ICD-10-PCS CODE PROCEDURE CLASS PROCEDURE CLASS NAME Category  \
# 0   1         0016070               4    Major Therapeutic     VSHN
# 1   2         0016071               4    Major Therapeutic     VSHN
# 2   3         0016072               4    Major Therapeutic     VSHN
# 3   4         0016073               4    Major Therapeutic     VSHN
# 4   5         0016074               4    Major Therapeutic     VSHN
# 5   6         0016075               4    Major Therapeutic     VSHN
# 6   7         0016076               4    Major Therapeutic     VSHN
# 7   8         0016077               4    Major Therapeutic     VSHN
# 8   9         0016078               4    Major Therapeutic     VSHN
# 9  10         001607A               4    Major Therapeutic     VSHN
#
#                                            Procedure        Anatomy Qualifier  \
# 0  Bypass Cerebral Ventricle to Nasopharynx with ...  Open Approach      None
# 1  Bypass Cerebral Ventricle to Mastoid Sinus wit...  Open Approach      None
# 2  Bypass Cerebral Ventricle to Atrium with Autol...  Open Approach      None
# 3  Bypass Cerebral Ventricle to Blood Vessel with...  Open Approach      None
# 4  Bypass Cerebral Ventricle to Pleural Cavity wi...  Open Approach      None
# 5  Bypass Cerebral Ventricle to Intestine with Au...  Open Approach      None
# 6  Bypass Cerebral Ventricle to Peritoneal Cavity...  Open Approach      None
# 7  Bypass Cerebral Ventricle to Urinary Tract wit...  Open Approach      None
# 8  Bypass Cerebral Ventricle to Bone Marrow with ...  Open Approach      None
# 9  Bypass Cerebral Ventricle to Subgaleal Space w...  Open Approach      None
#
#   Device_or_Method Approach_or_Group
# 0             None              None
# 1             None              None
# 2             None              None
# 3             None              None
# 4             None              None
# 5             None              None
# 6             None              None
# 7             None              None
# 8             None              None
# 9             None              None

# %%
ICD_10_PCS_code.to_csv("ICD_10_PCS_code.csv", index=False)
